# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import random;
from IPython.display import HTML

# %%
def swap(arr, i, j):
    """
    Swap the ith and jth entry in the array arr.
    Assume: i != j and i, j < len(arr)
    """
    tmp = arr[i]
    arr[i] = arr[j]
    arr[j] = tmp

# %%
def insertion_sort(arr):
    """
    In the ith pass of the first loop, the first i elements should be
    ordered. This actually modifies the input array.
    """
    for i in range(1, len(arr)):
        for j in range(0, i):
            # convenience variables 
            # l = curent item being looked at
            # k = item preceding the curent item
            l = i - j; k = l - 1
            if arr[k] > arr[l]: # prec > curr
                swap(arr, k, l)
            else:
                # Once prev <= curr stop this loop
                break

# %%
def gen_frame(arr, gen_fig = True):
    """
    In the ith pass of the first loop, the first i elements should be
    ordered. This actually modifies the input array.
    """
    for i in range(1, len(arr)):
        for j in range(0, i):
            # convenience variables 
            # l = curent item being looked at
            # k = item preceding the curent item
            l = i - j; k = l - 1
            if arr[k] > arr[l]: # prec > curr
                swap(arr, k, l)
                if gen_fig:
                    ax.cla()
                    yield ax.stem(arr)
                else:
                    yield 1
            else:
                # Once prev <= curr stop this loop
                break

def update(frame):
    return frame

def count_frames(frames):
    return sum(1 for frame in frames)

# %%
arr = random.choices(range(50), k = 100)

arr1 = arr[:] # Copy elements not pointer

num_frames = count_frames(gen_frame(arr1, gen_fig = False))

print("%d frames"%num_frames)

#insertion_sort(arr)

fig, ax = plt.subplots()

ani = FuncAnimation(fig, update, frames = gen_frame(arr), repeat=False, save_count=num_frames)
# Out:
# 2640 frames

# %%
HTML(ani.to_html5_video())
#ani.save("what.mp4")
# Out:
# <video width="432" height="288" controls autoplay>
#   <source type="video/mp4" src="...

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.axis([0, 10, 0, 1])

for i in range(10):
    y = np.random.random()
    plt.scatter(i, y)
    plt.pause(0.05)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

import numpy as np

fig, ax = plt.subplots()
x = np.linspace(0.1, 2*np.pi, 10)
#markerline, stemlines, baseline = ax.stem(x, np.cos(x), '-.')

i = 10

def gen_frames():
    i = 0
    while i < 110:
        ax.cla()
        ax.set_ylim((-1, 1))
        i += 10
        yield ax.stem(x, np.cos(x+i/10), '-.')

def update(frame):
    return frame

# %%
frames = gen_frames()

# %%
anim = FuncAnimation(fig, update, frames=frames, interval=500)
HTML(anim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
arr1
# Out:
# [0,
#  0,
#  0,
#  1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  4,
#  5,
#  6,
#  7,
#  8,
#  8,
#  8,
#  9,
#  9,
#  10,
#  10,
#  10,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  13,
#  13,
#  13,
#  14,
#  14,
#  15,
#  15,
#  16,
#  16,
#  16,
#  16,
#  16,
#  17,
#  18,
#  19,
#  19,
#  20,
#  21,
#  22,
#  23,
#  23,
#  24,
#  25,
#  25,
#  26,
#  26,
#  28,
#  29,
#  30,
#  30,
#  31,
#  31,
#  32,
#  32,
#  33,
#  34,
#  34,
#  34,
#  35,
#  35,
#  36,
#  36,
#  36,
#  37,
#  37,
#  38,
#  38,
#  39,
#  40,
#  41,
#  41,
#  42,
#  43,
#  43,
#  44,
#  44,
#  44,
#  44,
#  45,
#  45,
#  46,
#  46,
#  46,
#  47,
#  47,
#  48,
#  49,
#  49,
#  49,
#  49]

# %%
arr = random.choices(range(500), k = 20)
arr1 = arr
arr2 = arr

# %%
insertion_sort(arr1)

# %%
arr1
# Out:
# [60,
#  61,
#  68,
#  141,
#  165,
#  168,
#  253,
#  255,
#  258,
#  282,
#  291,
#  315,
#  341,
#  385,
#  385,
#  430,
#  452,
#  463,
#  467,
#  479]

# %%
arr2
# Out:
# [60,
#  61,
#  68,
#  141,
#  165,
#  168,
#  253,
#  255,
#  258,
#  282,
#  291,
#  315,
#  341,
#  385,
#  385,
#  430,
#  452,
#  463,
#  467,
#  479]
